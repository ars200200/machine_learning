# %%
import pandas as pd
from tqdm.auto import tqdm

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

sns.set(palette='summer')

# %%
# !pip install -q accelerate -U

# %%
# !pip install -q datasets

# %%
# !pip install -q transformers

# %%
# !pip install -q evaluate

# %%
import transformers
from datasets import load_dataset
import evaluate
# Out:
# /home/arsen/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# /home/arsen/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/utils/generic.py:260: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
device
# Out:
# 'cuda'

# %% [markdown]
# ## Подготовка данных

# %%
billsum = load_dataset("billsum", split="ca_test")
# Out:
# Found cached dataset parquet (/home/arsen/.cache/huggingface/datasets/parquet/billsum-35284aeeba767e98/0.0.0/2a3b91fbd88a2c90d1dbbb32b460cf621d31bd5b05b934492fdef7d8d6f236ec)

# %%
billsum
# Out:
# Dataset({
#     features: ['text', 'summary', 'title'],
#     num_rows: 1237
# })

# %%
billsum = billsum.train_test_split(test_size=0.1)

# %%
billsum
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'summary', 'title'],
#         num_rows: 1113
#     })
#     test: Dataset({
#         features: ['text', 'summary', 'title'],
#         num_rows: 124
#     })
# })

# %%
tokenizer = transformers.AutoTokenizer.from_pretrained("ainize/bart-base-cnn")

# %%
tokenizer
# Out:
# BartTokenizerFast(name_or_path='ainize/bart-base-cnn', vocab_size=50265, model_max_length=1000000000000000019884624838656, is_fast=True, padding_side='right', truncation_side='right', special_tokens={'bos_token': '<s>', 'eos_token': '</s>', 'unk_token': '<unk>', 'sep_token': '</s>', 'pad_token': '<pad>', 'cls_token': '<s>', 'mask_token': AddedToken("<mask>", rstrip=False, lstrip=True, single_word=False, normalized=False)}, clean_up_tokenization_spaces=True)

# %%
def preprocess_function(examples):
    model_inputs = tokenizer(examples["text"], max_length=1024, truncation=True)

    labels = tokenizer(text_target=examples["summary"], max_length=128, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
tokenized_billsum = billsum.map(preprocess_function, batched=True)
# Out:
# Map:   0%|          | 0/1113 [00:00<?, ? examples/s]
# Map:   0%|          | 0/124 [00:00<?, ? examples/s]

# %%
model = transformers.AutoModelForSeq2SeqLM.from_pretrained("ainize/bart-base-cnn")
# Out:
# Downloading pytorch_model.bin:   0%|          | 0.00/558M [00:00<?, ?B/s]

# %%
data_collator = transformers.DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)

# %%
training_args = transformers.Seq2SeqTrainingArguments(
        output_dir="./results",
        evaluation_strategy="epoch",
        learning_rate=2e-5,
        per_device_train_batch_size=4,
        per_device_eval_batch_size=4,
        weight_decay=0.01,
        save_total_limit=3,
        num_train_epochs=2,
    )

# %%
trainer = transformers.Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_billsum["train"],
    eval_dataset=tokenized_billsum["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
)
# Out:
# /home/arsen/anaconda3/envs/my_env/lib/python3.11/site-packages/accelerate/accelerator.py:446: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None)
#   warnings.warn(

# %%
trainer.train()
# Out:
# You're using a BartTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='2' max='558' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [  2/558 : < :, Epoch 0.00/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 trainer.train()
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/trainer.py:1555, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1553         hf_hub_utils.enable_progress_bars()
#    1554 else:
# -> 1555     return inner_training_loop(
#    1556         args=args,
#    1557         resume_from_checkpoint=resume_from_checkpoint,
#    1558         trial=trial,
#    1559         ignore_keys_for_eval=ignore_keys_for_eval,
#    1560     )
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/trainer.py:1837, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1834     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    1836 with self.accelerator.accumulate(model):
# -> 1837     tr_loss_step = self.training_step(model, inputs)
#    1839 if (
#    1840     args.logging_nan_inf_filter
#    1841     and not is_torch_tpu_available()
#    1842     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    1843 ):
#    1844     # if loss is nan or inf simply add the average of previous logged losses
#    1845     tr_loss += tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/trainer.py:2682, in Trainer.training_step(self, model, inputs)
#    2679     return loss_mb.reduce_mean().detach().to(self.args.device)
#    2681 with self.compute_loss_context_manager():
# -> 2682     loss = self.compute_loss(model, inputs)
#    2684 if self.args.n_gpu > 1:
#    2685     loss = loss.mean()  # mean() to average on multi-gpu parallel training
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/trainer.py:2707, in Trainer.compute_loss(self, model, inputs, return_outputs)
#    2705 else:
#    2706     labels = None
# -> 2707 outputs = model(**inputs)
#    2708 # Save past state if it exists
#    2709 # TODO: this needs to be fixed and made cleaner later.
#    2710 if self.args.past_index >= 0:
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:1388, in BartForConditionalGeneration.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1383     if decoder_input_ids is None and decoder_inputs_embeds is None:
#    1384         decoder_input_ids = shift_tokens_right(
#    1385             labels, self.config.pad_token_id, self.config.decoder_start_token_id
#    1386         )
# -> 1388 outputs = self.model(
#    1389     input_ids,
#    1390     attention_mask=attention_mask,
#    1391     decoder_input_ids=decoder_input_ids,
#    1392     encoder_outputs=encoder_outputs,
#    1393     decoder_attention_mask=decoder_attention_mask,
#    1394     head_mask=head_mask,
#    1395     decoder_head_mask=decoder_head_mask,
#    1396     cross_attn_head_mask=cross_attn_head_mask,
#    1397     past_key_values=past_key_values,
#    1398     inputs_embeds=inputs_embeds,
#    1399     decoder_inputs_embeds=decoder_inputs_embeds,
#    1400     use_cache=use_cache,
#    1401     output_attentions=output_attentions,
#    1402     output_hidden_states=output_hidden_states,
#    1403     return_dict=return_dict,
#    1404 )
#    1406 lm_logits = self.lm_head(outputs[0])
#    1407 lm_logits = lm_logits + self.final_logits_bias.to(lm_logits.device)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:1256, in BartModel.forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict)
#    1253 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1255 if encoder_outputs is None:
# -> 1256     encoder_outputs = self.encoder(
#    1257         input_ids=input_ids,
#    1258         attention_mask=attention_mask,
#    1259         head_mask=head_mask,
#    1260         inputs_embeds=inputs_embeds,
#    1261         output_attentions=output_attentions,
#    1262         output_hidden_states=output_hidden_states,
#    1263         return_dict=return_dict,
#    1264     )
#    1265 # If the user passed a tuple for encoder_outputs, we wrap it in a BaseModelOutput when return_dict=True
#    1266 elif return_dict and not isinstance(encoder_outputs, BaseModelOutput):
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:871, in BartEncoder.forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#     864         layer_outputs = torch.utils.checkpoint.checkpoint(
#     865             create_custom_forward(encoder_layer),
#     866             hidden_states,
#     867             attention_mask,
#     868             (head_mask[idx] if head_mask is not None else None),
#     869         )
#     870     else:
# --> 871         layer_outputs = encoder_layer(
#     872             hidden_states,
#     873             attention_mask,
#     874             layer_head_mask=(head_mask[idx] if head_mask is not None else None),
#     875             output_attentions=output_attentions,
#     876         )
#     878     hidden_states = layer_outputs[0]
#     880 if output_attentions:
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:332, in BartEncoderLayer.forward(self, hidden_states, attention_mask, layer_head_mask, output_attentions)
#     320 """
#     321 Args:
#     322     hidden_states (`torch.FloatTensor`): input to the layer of shape `(batch, seq_len, embed_dim)`
#    (...)
#     329         returned tensors for more detail.
#     330 """
#     331 residual = hidden_states
# --> 332 hidden_states, attn_weights, _ = self.self_attn(
#     333     hidden_states=hidden_states,
#     334     attention_mask=attention_mask,
#     335     layer_head_mask=layer_head_mask,
#     336     output_attentions=output_attentions,
#     337 )
#     338 hidden_states = nn.functional.dropout(hidden_states, p=self.dropout, training=self.training)
#     339 hidden_states = residual + hidden_states
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1532, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1530     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1531 else:
# -> 1532     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/torch/nn/modules/module.py:1541, in Module._call_impl(self, *args, **kwargs)
#    1536 # If we don't have any hooks, we want to skip the rest of the logic in
#    1537 # this function, and just call forward.
#    1538 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1539         or _global_backward_pre_hooks or _global_backward_hooks
#    1540         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1541     return forward_call(*args, **kwargs)
#    1543 try:
#    1544     result = None
#
# File ~/anaconda3/envs/my_env/lib/python3.11/site-packages/transformers/models/bart/modeling_bart.py:250, in BartAttention.forward(self, hidden_states, key_value_states, past_key_value, attention_mask, layer_head_mask, output_attentions)
#     246     if attention_mask.size() != (bsz, 1, tgt_len, src_len):
#     247         raise ValueError(
#     248             f"Attention mask should be of size {(bsz, 1, tgt_len, src_len)}, but is {attention_mask.size()}"
#     249         )
# --> 250     attn_weights = attn_weights.view(bsz, self.num_heads, tgt_len, src_len) + attention_mask
#     251     attn_weights = attn_weights.view(bsz * self.num_heads, tgt_len, src_len)
#     253 attn_weights = nn.functional.softmax(attn_weights, dim=-1)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 192.00 MiB. GPU

# %% [markdown]
# ###  Предсказания на тестовом множестве

# %%
text_example = billsum["test"]['text'][0]
print(text_example)

# %%
input_ids = tokenizer.encode(
    text_example,
    return_tensors="pt",
    max_length=1024,
    truncation=True,
    ).to(device)

# %%
input_ids.shape

# %%
summary_text_ids = model.generate(
    input_ids=input_ids,
    bos_token_id=model.config.bos_token_id,
    eos_token_id=model.config.eos_token_id,
    max_length=142,
    min_length=56,
    num_beams=4,
)

# %%
summary_text_ids

# %%
decoded_text = tokenizer.decode(summary_text_ids[0], skip_special_tokens=True)

# %%
len(decoded_text), len(text_example)

# %%
decoded_text

# %%
summaries = []

for text in tqdm(billsum["test"]['text']):
    input_ids = tokenizer.encode(
        text,
        return_tensors="pt",
        max_length=1024,
        truncation=True,
        ).to(device)

    summary_text_ids = model.generate(
        input_ids=input_ids,
        bos_token_id=model.config.bos_token_id,
        eos_token_id=model.config.eos_token_id,
        max_length=142,
        min_length=56,
        num_beams=4,
    )

    decoded_text = tokenizer.decode(summary_text_ids[0], skip_special_tokens=True)
    summaries.append(decoded_text)

# %% [markdown]
# ## Считаем качество

# %% [markdown]
# ### ROUGE

# %%
# !pip install rouge_score

# %%
rouge = evaluate.load('rouge')

# %%
# %%time
results = rouge.compute(
        predictions=summaries,
        references=billsum["test"]['summary']
    )

# %%
results
